# %%
import pandas as pd 
import numpy as np
Location = r"C:\Users\sake1\Documents\DV\datasets\datasets\gradedata.csv"
df = pd.read_csv(Location)

# %%
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 1462  Zenaida       Ross  female   18         3     10   87.4
# 811   Malcolm       Peck    male   19         4     10   82.6
# 861     Paula    Mcbride  female   17         5      6   69.2
# 10     Daquan    Alvarez    male   16         2     13   85.2
# 225     Naida   Delacruz  female   17         2      9   70.3
# ...       ...        ...     ...  ...       ...    ...    ...
# 1613   Warren     Garcia    male   16         2     12   82.3
# 1285   Samuel    Beasley    male   19         1     15   90.6
# 1369    Dolan       Hyde    male   17         1     17  100.0
# 252      Rose  Middleton  female   15         2     20  100.0
# 186       Gay     Wagner  female   17         4      7   75.0
#
#                                            address
# 1462       98 Main Circle, Atlantic City, NJ 08401
# 811         7 Linda Ave., Council Bluffs, IA 51501
# 861   7007 Delaware St., Franklin Square, NY 11010
# ...
